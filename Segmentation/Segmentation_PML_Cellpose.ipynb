# %%
#PML / Nuc by cellpose 

from cellpose import models
from cellpose.io import imread

# model_type='cyto' or model_type='nuclei'
model = models.Cellpose(gpu=False, model_type='cyto')
file = ['/Users/zg/Mammouth/PROJECTS/Analysis/Image_Choice/MAX_PMLwt_20_MMStack_Pos0.ome-1-Nuc.tif']
#files = ['/Users/zg/Mammouth/PROJECTS/Analysis/Image_Choice/MAX_PMLwt_20_MMStack_Pos0.ome-1-Nuc.tif', '/Users/zg/Mammouth/PROJECTS/Analysis/Image_Choice/MAX_PMLwt_20_MMStack_Pos0.ome-1-PML.tif']
imgs = [imread(f) for f in file]
masks, flows, styles, diams = model.eval(imgs, diameter=None, channels=[0,0],
                                         flow_threshold=0.4, do_3D=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       9 #files = ['/Users/zg/Mammouth/PROJECTS/Analysis/Image_Choice/MAX_PMLwt_20_MMStack_Pos0.ome-1-Nuc.tif', '/Users/zg/Mammouth/PROJECTS/Analysis/Image_Choice/MAX_PMLwt_20_MMStack_Pos0.ome-1-PML.tif']
#      10 imgs = [imread(f) for f in file]
# ---> 11 masks, flows, styles, diams = model.eval(imgs, diameter=None, channels=[0,0],
#      12                                          flow_threshold=0.4, do_3D=False)
#
# File /opt/anaconda3/envs/cellpose-env/lib/python3.9/site-packages/cellpose/models.py:164, in Cellpose.eval(self, x, batch_size, channels, channel_axis, invert, normalize, diameter, do_3D, **kwargs)
#     162 tic = time.time()
#     163 models_logger.info("~~~ ESTIMATING CELL DIAMETER(S) ~~~")
# --> 164 diams, _ = self.sz.eval(x, channels=channels, channel_axis=channel_axis,
# ...
